# %%
#import visualization
import matplotlib.pyplot as plt
import seaborn as sns

#import numpy and pandas
import numpy as np
import pandas as pd

#import preprocessing
from sklearn import preprocessing

# %%
#import csv automobile-losses
losses = pd.read_csv("automobile-losses.csv")
losses.head()
# Out:
#    ID  normalized-losses
# 0   1                NaN
# 1   2                NaN
# 2   3                NaN
# 3   4              164.0
# 4   5              164.0

# %%
#import csv automobile-risk
risk = pd.read_csv('automobile-risk.csv')
risk.head()
# Out:
#    ID  symboling
# 0   1          3
# 1   2          3
# 2   3          1
# 3   4          2
# 4   5          2

# %%
#import csv automobile-spec
spec = pd.read_csv('automobile-spec.csv')
spec.head()
# Out:
#    ID         make fuel-type aspiration num-of-doors   body-style drive-wheel  \
# 0   1  alfa-romero       gas        std          two  convertible         rwd
# 1   2  alfa-romero       gas        std          two  convertible         rwd
# 2   3  alfa-romero       gas        std          two    hatchback         rwd
# 3   4         audi       gas        std         four        sedan         fwd
# 4   5         audi       gas        std         four        sedan         4wd
#
#   engine-loc  wheel-base  length   ...     engine-size  fuel-system  bore  \
# 0      front        88.6   168.8   ...             130         mpfi  3.47
# 1      front        88.6   168.8   ...             130         mpfi  3.47
# 2      front        94.5   171.2   ...             152         mpfi  2.68
# 3      front        99.8   176.6   ...             109         mpfi  3.19
# 4      front        99.4   176.6   ...             136         mpfi  3.19
#
# ...

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### 1. Join 3 tables using ID as key

# %%
#join table losses, risk, and spec
join = pd.merge(pd.merge(losses,risk,on='ID'),spec,on='ID')
join
# Out:
#       ID  normalized-losses  symboling         make fuel-type aspiration  \
# 0      1                NaN          3  alfa-romero       gas        std
# 1      2                NaN          3  alfa-romero       gas        std
# 2      3                NaN          1  alfa-romero       gas        std
# 3      4              164.0          2         audi       gas        std
# 4      5              164.0          2         audi       gas        std
# 5      6                NaN          2         audi       gas        std
# 6      7              158.0          1         audi       gas        std
# 7      8                NaN          1         audi       gas        std
# 8      9              158.0          1         audi       gas      turbo
# 9     10                NaN          0         audi       gas      turbo
# 10    11              192.0          2          bmw       gas        std
# 11    12              192.0          0          bmw       gas        std
# ...

# %% [markdown]
# ### 2. Quick-look (dimension, data type, head/tail, summary statistics, etc)

# %%
#dimension
join.shape
# Out:
# (205, 27)

# %%
#data type
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 27 columns):
# ID                   205 non-null int64
# normalized-losses    164 non-null float64
# symboling            205 non-null int64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         204 non-null object
# body-style           205 non-null object
# drive-wheel          205 non-null object
# engine-loc           205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# cylinder             205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 201 non-null float64
# ...

# %%
#head
join.head()
# Out:
#    ID  normalized-losses  symboling         make fuel-type aspiration  \
# 0   1                NaN          3  alfa-romero       gas        std
# 1   2                NaN          3  alfa-romero       gas        std
# 2   3                NaN          1  alfa-romero       gas        std
# 3   4              164.0          2         audi       gas        std
# 4   5              164.0          2         audi       gas        std
#
#   num-of-doors   body-style drive-wheel engine-loc   ...     engine-size  \
# 0          two  convertible         rwd      front   ...             130
# 1          two  convertible         rwd      front   ...             130
# 2          two    hatchback         rwd      front   ...             152
# 3         four        sedan         fwd      front   ...             109
# 4         four        sedan         4wd      front   ...             136
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
#tail
join.tail()
# Out:
#       ID  normalized-losses  symboling   make fuel-type aspiration  \
# 200  201               95.0         -1  volvo       gas        std
# 201  202               95.0         -1  volvo       gas      turbo
# 202  203               95.0         -1  volvo       gas        std
# 203  204               95.0         -1  volvo    diesel      turbo
# 204  205               95.0         -1  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheel engine-loc   ...     engine-size  \
# 200         four      sedan         rwd      front   ...             141
# 201         four      sedan         rwd      front   ...             141
# 202         four      sedan         rwd      front   ...             173
# 203         four      sedan         rwd      front   ...             145
# 204         four      sedan         rwd      front   ...             141
#
#      fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# ...

# %%
#summary statistic
join.describe()
# Out:
#                ID  normalized-losses   symboling  wheel-base      length  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean   103.000000         122.000000    0.834146   98.756585  174.049268
# std     59.322565          35.442168    1.245307    6.021776   12.337289
# min      1.000000          65.000000   -2.000000   86.600000  141.100000
# 25%     52.000000          94.000000    0.000000   94.500000  166.300000
# 50%    103.000000         115.000000    1.000000   97.000000  173.200000
# 75%    154.000000         150.000000    2.000000  102.400000  183.100000
# max    205.000000         256.000000    3.000000  120.900000  208.100000
#
#             width      height  curb-weight  engine-size        bore  \
# count  205.000000  205.000000   205.000000   205.000000  201.000000
# mean    65.907805   53.724878  2555.565854   126.907317    3.329751
# std      2.145204    2.443522   520.680204    41.642693    0.273539
# ...

# %% [markdown]
# ### 3. Identify missing value. If any, how will you handle it

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 27 columns):
# ID                   205 non-null int64
# normalized-losses    164 non-null float64
# symboling            205 non-null int64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         204 non-null object
# body-style           205 non-null object
# drive-wheel          205 non-null object
# engine-loc           205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# cylinder             205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 201 non-null float64
# ...

# %%
#make array numerical and categorical
num = ['make', 'fuel-type', 'aspiration','num-of-doors', 'body-style', 'drive-wheel','engine-loc', 'engine-type', 'cylinder','fuel-system']
numerical=join.drop(num,axis=1)
categorical=join[num]
numerical.head()
# Out:
#    ID  normalized-losses  symboling  wheel-base  length  width  height  \
# 0   1                NaN          3        88.6   168.8   64.1    48.8
# 1   2                NaN          3        88.6   168.8   64.1    48.8
# 2   3                NaN          1        94.5   171.2   65.5    52.4
# 3   4              164.0          2        99.8   176.6   66.2    54.3
# 4   5              164.0          2        99.4   176.6   66.4    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0        21           27  13495.0
# ...

# %%
join.isnull().sum().sort_values(ascending=False) #detect missing value
# Out:
# normalized-losses    41
# price                 4
# stroke                4
# bore                  4
# peak-rpm              2
# horsepower            2
# num-of-doors          1
# wheel-base            0
# symboling             0
# make                  0
# fuel-type             0
# aspiration            0
# body-style            0
# drive-wheel           0
# engine-loc            0
# height                0
# length                0
# width                 0
# highway-mpg           0
# curb-weight           0
# engine-type           0
# cylinder              0
# engine-size           0
# fuel-system           0
# compression-ratio     0
# city-mpg              0
# ID                    0
# dtype: int64

# %%
nanull = join.fillna(join.median()).head() #mengisi missing value pakai median
nanull.isnull().sum().sort_values(ascending=False) #detect missing value
# Out:
# price                0
# width                0
# normalized-losses    0
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheel          0
# engine-loc           0
# wheel-base           0
# length               0
# height               0
# highway-mpg          0
# curb-weight          0
# engine-type          0
# cylinder             0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# ID                   0
# dtype: int64

# %%
join.fillna(join.median()).head()
# Out:
#    ID  normalized-losses  symboling         make fuel-type aspiration  \
# 0   1              115.0          3  alfa-romero       gas        std
# 1   2              115.0          3  alfa-romero       gas        std
# 2   3              115.0          1  alfa-romero       gas        std
# 3   4              164.0          2         audi       gas        std
# 4   5              164.0          2         audi       gas        std
#
#   num-of-doors   body-style drive-wheel engine-loc   ...     engine-size  \
# 0          two  convertible         rwd      front   ...             130
# 1          two  convertible         rwd      front   ...             130
# 2          two    hatchback         rwd      front   ...             152
# 3         four        sedan         fwd      front   ...             109
# 4         four        sedan         4wd      front   ...             136
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
numerical.describe()
# Out:
#                ID  normalized-losses   symboling  wheel-base      length  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean   103.000000         122.000000    0.834146   98.756585  174.049268
# std     59.322565          35.442168    1.245307    6.021776   12.337289
# min      1.000000          65.000000   -2.000000   86.600000  141.100000
# 25%     52.000000          94.000000    0.000000   94.500000  166.300000
# 50%    103.000000         115.000000    1.000000   97.000000  173.200000
# 75%    154.000000         150.000000    2.000000  102.400000  183.100000
# max    205.000000         256.000000    3.000000  120.900000  208.100000
#
#             width      height  curb-weight  engine-size        bore  \
# count  205.000000  205.000000   205.000000   205.000000  201.000000
# mean    65.907805   53.724878  2555.565854   126.907317    3.329751
# std      2.145204    2.443522   520.680204    41.642693    0.273539
# ...

# %% [markdown]
# ### 4. Perform visualization using at least 5 difference visualization technique (barplot, scatter plot, area, boxplot, pie chart, line chart, etc)

# %% [markdown]
# #### Histogram

# %%
plt.hist(join['make'], 
         facecolor='blue', 
         edgecolor='maroon', 
         bins=8)

plt.show()

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 204
# Data columns (total 27 columns):
# ID                   205 non-null int64
# normalized-losses    164 non-null float64
# symboling            205 non-null int64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         204 non-null object
# body-style           205 non-null object
# drive-wheel          205 non-null object
# engine-loc           205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# cylinder             205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 201 non-null float64
# ...

# %% [markdown]
# ### Boxplot

# %%
join_array = np.array(join[['city-mpg','highway-mpg']])

# %%
colors = ['blue', 'grey', 'lawngreen']

bp = plt.boxplot(join_array, 
                 patch_artist=True,
                 notch=True)

for i in range(len(bp['boxes'])):
    
    bp['boxes'][i].set(facecolor=colors[i])
    
    bp['caps'][2*i + 1].set(color=colors[i])
    
plt.xticks([1, 2], ['city-mpg','highway-mpg'])

plt.show()

# %% [markdown]
# ### Bar Plot

# %%
#filter by full-type=gas
data_gas = join[join['fuel-type']=='gas']
top_10_g=data_gas.sort_values('curb-weight',ascending=False).head(10)

# %%
plt.figure(figsize=(12,6))

x=range(10)
plt.bar(x,top_10_g['curb-weight']/10**9)
plt.xticks(x,top_10_g['make'])
plt.xlabel('Type of Cars')
plt.ylabel('Curb Weight')
plt.title('10 Most Fuel Type In Cars')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(data_gas['city-mpg'],data_gas['highway-mpg'])
plt.title('Combined Driving and Highway Driving Miles per Gallon in Vehicles')
plt.xlabel('Combined Driving')
plt.ylabel('Highway Driving')
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
joins = join[['fuel-system','engine-size']]
joins.head()
# Out:
#   fuel-system  engine-size
# 0        mpfi          130
# 1        mpfi          130
# 2        mpfi          152
# 3        mpfi          109
# 4        mpfi          136

# %%
join_group = joins.groupby('fuel-system').mean()
join_group.head()
# Out:
#              engine-size
# fuel-system
# 1bbl           97.363636
# 2bbl          100.227273
# 4bbl           70.000000
# idi           135.700000
# mfi           156.000000

# %%
plt.figure(figsize=(8,8))
plt.pie(join_group, 
        labels=join_group.index, autopct='%.2f')

plt.axis('equal')
plt.show()

# %% [markdown]
# ### Countplot

# %%
fig=plt.figure(figsize=(13,12))
fig.add_subplot(3,3,1)
sns.countplot(numerical['normalized-losses'])
fig.add_subplot(3,3,2)
sns.countplot(numerical['symboling'])
fig.add_subplot(3,3,3)
sns.distplot(numerical['wheel-base'])
fig.add_subplot(3,3,4)
sns.countplot(numerical['length'])
fig.add_subplot(3,3,5)
sns.countplot(numerical['width'])
fig.add_subplot(3,3,6)
sns.countplot(numerical['height'])
fig.add_subplot(3,3,7)
sns.distplot(numerical['curb-weight'])
fig.add_subplot(3,3,8)
sns.distplot(numerical['engine-size'])

# %% [markdown]
# ### Violin

# %%
vp = plt.violinplot(join_array,
                    showmedians=True)

plt.xticks([1, 2], ['city-mpg','highway-mpg'])

for i in range(len(vp['bodies'])):
    vp['bodies'][i].set(facecolor='darkblue')

plt.show()

# %% [markdown]
# ### Doughnut Chart

# %%
# Create a circle for the center of the plot
plt.figure(figsize=(8,8))
plt.axis('equal')
my_circle=plt.Circle( (0,0), 0.7, color='white')
my_circle
# Give color names
plt.pie(join_group, labels=join_group.index, colors=['red','green','blue','skyblue'], autopct='%.2f')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
import seaborn as sns
sns.pairplot(join[['city-mpg', 'horsepower', 'engine-size', 'curb-weight', 'price', 'fuel-type']], hue='fuel-type', diag_kind='hist')
# Out:
# C:\Users\nurlai064182\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:29: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims)
# C:\Users\nurlai064182\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# C:\Users\nurlai064182\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:780: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\nurlai064182\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:781: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ## PART 2

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %% [markdown]
# #### 1. Car brand with highest price

# %%
carbrand = join.groupby('make').price.max().reset_index()
data_sort = carbrand.sort_values(by='price', ascending=False).reset_index()
data_sort.drop(columns='index').head(1)
print(color.BOLD + '%s is car brand with highest price' % data_sort['make'].values[0])
# Out:
# mercedes-benz is car brand with highest price

# %% [markdown]
# #### 2. Maximum horsepower for car with 6 cylinder engine

# %%
max_horse = join[join['cylinder']=='six']
print('%s is the maximum horpower for car with 6 cylinder engine' % max_horse['horsepower'].max())
# Out:
# 207.0 is the maximum horpower for car with 6 cylinder engine

# %% [markdown]
# #### 3. Average peak-rpm for ‘turbo’ style aspiration car

# %%
avg1 = join[join['aspiration']=='turbo']
data_avg = avg1['peak-rpm'].mean()
data_avg
print('Average peak-rpm for ‘turbo’ style aspiration car is %.2f' % avg1['peak-rpm'].mean())
# Out:
# Average peak-rpm for ‘turbo’ style aspiration car is 4939.19

# %% [markdown]
# #### 4. Average price based on body-style

# %%
caravg1 = join.groupby('body-style').price.mean().sort_values().reset_index()
caravg1
# Out:
#     body-style         price
# 0    hatchback   9957.441176
# 1        wagon  12371.960000
# 2        sedan  14459.755319
# 3  convertible  21890.500000
# 4      hardtop  22208.500000

# %% [markdown]
# #### 5. Average price based on body-style only for Honda car (make=Honda)

# %%
avg2 = join[join['make']=='honda']
caravg = avg2.groupby('body-style').price.mean().sort_values().reset_index()
caravg
# Out:
#   body-style        price
# 0  hatchback  7054.428571
# 1      wagon  7295.000000
# 2      sedan  9945.000000
